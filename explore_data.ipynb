# %%
import pandas as pd

df = pd.read_parquet("data/raw_advanced/team_advanced_2020-21.parquet")
# Show all columns
pd.set_option('display.max_columns', None)

# Optional: show all rows (be careful for huge datasets)
pd.set_option('display.max_rows', None)

# Optional: widen the display
pd.set_option('display.width', 200)

# Load the parquet
df = pd.read_parquet("data/raw_advanced/team_advanced_2020-21.parquet")

# Print shape and the full dataframe
print(df.shape)
print(df.head())  # head() is safer than printing the whole thing
# Out:
# (30, 33)
#       TEAM_ID   season  win         PTS  points_against        FGM        FGA       FG3M       FG3A        FTM        FTA        REB        AST        TOV       STL       BLK         PF  point_diff  \
# 0  1610612737  2020-21   41  113.694444      111.375000  40.791667  87.236111  12.430556  33.361111  19.680556  24.236111  45.625000  24.125000  13.236111  6.986111  4.750000  19.333333    2.319444
# 1  1610612738  2020-21   36  112.625000      111.166667  41.458333  88.902778  13.597222  36.361111  16.111111  20.777778  44.250000  23.458333  14.055556  7.722222  5.319444  20.430556    1.458333
# 2  1610612739  2020-21   22  103.833333      112.277778  38.583333  85.763889  10.000000  29.736111  16.666667  22.416667  42.750000  23.833333  15.472222  7.763889  4.513889  18.166667   -8.444444
# ...
