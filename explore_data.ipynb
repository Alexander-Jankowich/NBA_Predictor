# %%
import pandas as pd

df = pd.read_parquet("data/ml/team_season_2020-21.parquet")
df = pd.read_parquet("data/ml/team_season_2021-22.parquet")
print(df.shape)
df
# Out:
#        TEAM_ID   season  win         PTS  points_against        FGM  \
# 0   1610612737  2021-22   43  113.939024      112.378049  41.475610
# 1   1610612738  2021-22   51  111.756098      104.475610  40.743902
# 2   1610612739  2021-22   44  107.792683      105.670732  39.695122
# 3   1610612740  2021-22   36  109.292683      110.280488  40.170732
# 4   1610612741  2021-22   46  111.609756      112.000000  41.731707
# 5   1610612742  2021-22   52  108.024390      104.719512  39.292683
# 6   1610612743  2021-22   48  112.719512      110.414634  41.658537
# 7   1610612744  2021-22   53  111.000000      105.463415  40.524390
# 8   1610612745  2021-22   20  109.719512      118.195122  39.378049
# 9   1610612746  2021-22   42  108.414634      108.390244  40.060976
# 10  1610612747  2021-22   33  112.097561      115.146341  41.646341
# 11  1610612748  2021-22   53  110.024390      105.573171  39.585366
# 12  1610612749  2021-22   51  115.487805      112.134146  41.817073
# ...
