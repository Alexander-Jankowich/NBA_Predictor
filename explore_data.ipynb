# %%
import pandas as pd

df = pd.read_parquet("data/ml/team_season_2020-21.parquet")
df
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME  \
# 0        22020  1610612746               LAC            LA Clippers
# 1        22020  1610612747               LAL     Los Angeles Lakers
# 2        22020  1610612744               GSW  Golden State Warriors
# 3        22020  1610612751               BKN          Brooklyn Nets
# 4        22020  1610612739               CLE    Cleveland Cavaliers
# ...        ...         ...               ...                    ...
# 2155     22020  1610612762               UTA              Utah Jazz
# 2156     22020  1610612763               MEM      Memphis Grizzlies
# 2157     22020  1610612765               DET        Detroit Pistons
# 2158     22020  1610612748               MIA             Miami Heat
# 2159     22020  1610612766               CHA      Charlotte Hornets
#
#          GAME_ID   GAME_DATE      MATCHUP WL  MIN  FGM  ...  DREB  REB  AST  \
# ...
